# %%
from Data.LocalState.LocalState import LocalState
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationX.脚本 import main
from Data.State.State import State
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
x_0=LocalState(2,np.array([1/np.sqrt(2),1/np.sqrt(2)]))
x_1=LocalState(2,np.array([1/np.sqrt(2),-1/np.sqrt(2)]))
state_array = [np.array([[x_0,x], [x,y], [x,y],[x,x_1]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0
g_z=0.1
disorder=1
t_list = np.linspace(0, 1000, 100)
disorder_type='sigmaz'
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi,disorder_type)

# %%
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationX.脚本 import main
from Data.State.State import State
import numpy as np
from Data.LocalState.LocalState import LocalState


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
x_0=LocalState(2,np.array([1/np.sqrt(2),1/np.sqrt(2)]))
x_1=LocalState(2,np.array([1/np.sqrt(2),-1/np.sqrt(2)]))
state_array = [np.array([[x_0,x_0], [x_1,x_0], [x_1,x_0],[x_0,x_1]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0
g_z=0
disorder=1
t_list = np.linspace(0, 1000, 100)
disorder_type='sigmax'
expectation_type='sigmax'
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi,disorder_type, expectation_type)

# %%
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationX.脚本 import main
from Data.State.State import State
import numpy as np
from Data.LocalState.LocalState import LocalState


##  构造初态
z_up = LocalState(2, np.array([1, 0]))
z_down = LocalState(2, np.array([0, 1]))
x_up = LocalState(2, np.array([1 / np.sqrt(2), 1 / np.sqrt(2)]))
x_down = LocalState(2, np.array([1 / np.sqrt(2), -1 / np.sqrt(2)]))
state_array = [np.array([[x_up,z_down], [z_up, z_down],[z_up,z_down], [z_up, x_down]])]
psi = State()
psi.initial(state_array)
N = 4
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0
disorder = 1
t_list = np.linspace(0, 10000, 1000)
disorder_type = 'sigmaz'
expectation_type='sigmax'
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi, disorder_type,expectation_type)

# %%
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationX.脚本 import main
from Data.State.State import State
import numpy as np
from Data.LocalState.LocalState import LocalState


##  构造初态
z_up = LocalState(2, np.array([1, 0]))
z_down = LocalState(2, np.array([0, 1]))
x_up = LocalState(2, np.array([1 / np.sqrt(2), 1 / np.sqrt(2)]))
x_down = LocalState(2, np.array([1 / np.sqrt(2), -1 / np.sqrt(2)]))
state_array = [np.array([[x_up,z_down], [z_up, z_down],[z_up,z_down], [z_up, x_down]])]
psi = State()
psi.initial(state_array)
N = 4
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0
disorder = 2
t_list = np.linspace(0, 1000, 200)
disorder_type = ['sigmax','sigmaz']
expectation_type='sigmax'
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi, disorder_type,expectation_type)

# %%
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationX.脚本 import main
from Data.State.State import State
import numpy as np
from Data.LocalState.LocalState import LocalState


##  构造初态
z_up = LocalState(2, np.array([1, 0]))
z_down = LocalState(2, np.array([0, 1]))
x_up = LocalState(2, np.array([1 / np.sqrt(2), 1 / np.sqrt(2)]))
x_down = LocalState(2, np.array([1 / np.sqrt(2), -1 / np.sqrt(2)]))
state_array = [
    np.array([[x_up, z_down],[z_up, z_down], [z_up, z_down], [z_up, x_down]])]
psi = State()
psi.initial(state_array)
N = 4
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0
disorder = 1
t_list = np.linspace(0, 100, 500)
disorder_type = 'sigmaz'
expectation_type = 'sigmax'
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi, disorder_type, expectation_type)
