# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np
from SSH模型中的多体局域化.EdgeStateLocalizationExpectationZ.脚本 import main


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0
g_z=0.1
disorder=1
t_list=np.linspace(0,100,200)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0
g_z=0.1
disorder=0.5
t_list=np.linspace(0,100,200)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0
g_z=0.1
disorder=0.1
t_list=np.linspace(0,100,200)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x = LocalState(2, np.array([1, 0]))
y = LocalState(2, np.array([0, 1]))
state_array = [np.array([[x, y], [x, y], [x, y], [x, y]])]
psi = State()
psi.initial(state_array)
N = 4
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0.1
disorder = 0
t_list = np.linspace(0, 100, 200)
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x = LocalState(2, np.array([1, 0]))
y = LocalState(2, np.array([0, 1]))
state_array = [np.array([[y, y], [x, y], [x, y], [x, x],[y,y]])]
psi = State()
psi.initial(state_array)
N = 5
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0.1
disorder = 0
t_list = np.linspace(0, 100, 200)
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x = LocalState(2, np.array([1, 0]))
y = LocalState(2, np.array([0, 1]))
state_array = [np.array([[x, y], [x, y], [x, y], [x, x], [y, y]])]
psi = State()
psi.initial(state_array)
N = 5
J_1 = 1
J_2 = 4
J_z = 0
g_z = 0.1
disorder = 0
t_list = np.linspace(0, 200, 200)
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x = LocalState(2, np.array([1, 0]))
y = LocalState(2, np.array([0, 1]))
state_array = [np.array([[x, y], [x, y], [x, y], [x, x], [y, y]])]
psi = State()
psi.initial(state_array)
N = 5
J_1 = 1
J_2 = 4
J_z = 0.1
g_z = 0.1
disorder = 0
t_list = np.linspace(0, 200, 200)
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np



##  构造初态
x = LocalState(2, np.array([1, 0]))
y = LocalState(2, np.array([0, 1]))
state_array = [np.array([[x, y], [x, y], [x, y], [x, x], [y, y]])]
psi = State()
psi.initial(state_array)
N = 5
J_1 = 1
J_2 = 4
J_z = 0.1
g_z = 0.5
disorder = 0
t_list = np.linspace(0, 10000, 2000)
main(N, J_1, J_2, J_z, g_z, disorder, t_list, psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0.1
g_z=0.1
disorder=1
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0.1
g_z=0.1
disorder=0.1
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0.1
g_z=0.1
disorder=0.001
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y],[x,y]])]
psi=State()
psi.initial(state_array)
N=5
J_1=1
J_2=4
J_z=0
g_z=0.1
disorder=0.001
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y],[x,y]])]
psi=State()
psi.initial(state_array)
N=5
J_1=1
J_2=4
J_z=0.1
g_z=0.1
disorder=0.001
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([[x,y], [x,y], [x,y], [x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=0.3
g_z=0.1
disorder=1
t_list = np.linspace(0, 2000, 500)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)

# %%
from Data.State.State import State
from Data.State.LocalState import LocalState
import numpy as np


##  构造初态
x=LocalState(2,np.array([1,0]))
y=LocalState(2,np.array([0,1]))
state_array = [np.array([ [x,y], [x,y], [x,y],[x,y]])]
psi=State()
psi.initial(state_array)
N=4
J_1=1
J_2=4
J_z=1
g_z=0.1
disorder=1
t_list = np.linspace(0, 10000, 1000)
main(N,J_1,J_2,J_z,g_z,disorder,t_list,psi)
